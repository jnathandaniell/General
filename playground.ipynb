# %%
params = [
    'Mutation',
    'Crossover',
    'Selection',
    'Mask Adj Rate',
    'Population',
    'Generations'
]
vals = [
    'Gaussian',
    'Uniform',
    'Tournament',
    '-',
    '-',
    '-'
]
secondary_vals = [
    '0.25',
    '0.75',
    '10',
    '0.2',
    '10,000',
    '50'
]
group = [
    'EA Operator',
    'EA Operator',
    'EA Operator',
    'Hyperparameter',
    'Hyperparameter',
    'Hyperparameter',
]

# %%
import pandas as pd

d = {
    'Parameter': params,
    'Type': vals,
    'Value': secondary_vals,
    'Group': group
}
frame = pd.DataFrame(d)

# %%
from great_tables import GT

(
    GT(frame)
    .tab_stub('Parameter', 'Group')
    .save('table_1.png')
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 6
#       1 from great_tables import GT
#       3 (
#       4     GT(frame)
#       5     .tab_stub('Parameter', 'Group')
# ----> 6     .save('table_1.png')
#       7 )
#
# File c:\Users\jnath\miniconda3\envs\general\Lib\site-packages\great_tables\_export.py:370, in save(self, file, selector, scale, expand, web_driver, window_size, debug_port, encoding, _debug_dump)
#     304 """
#     305 Produce a high-resolution image file or PDF of the table.
#     306
#    (...)
#     366
#     367 """
#     369 # Import the required packages
# --> 370 _try_import(name="selenium", pip_install_line="pip install selenium")
#     372 from selenium import webdriver
#     374 if selector != "table":
#
# File c:\Users\jnath\miniconda3\envs\general\Lib\site-packages\great_tables\_utils.py:28, in _try_import(name, pip_install_line)
# ...
