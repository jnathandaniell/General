# %%
from utilities.spheres.sphere_generator import build_sphere, add_noise
from utilities.jimmyplot.surfaceplot import get_surface_plot

# %%
sphere = build_sphere(r=1, n=100)
noisy_sphere = add_noise(sphere)
full_sphere = build_sphere(r=1, n=100, full=True)
noisy_full_sphere = add_noise(full_sphere)

# %%
labels = ('x', 'y', 'z')
angle = (30, 45, 0)

# %%
xyz = sphere[0,:], sphere[1,:], sphere[-1,:]
fig = get_surface_plot(xyz, labels=labels, angle=angle)

# %%
xyz = noisy_sphere[0,:], noisy_sphere[1,:], noisy_sphere[-1,:]
noisy_fig = get_surface_plot(xyz, labels=labels, angle=angle)

# %%
xyz = full_sphere[0,:], full_sphere[1,:], full_sphere[-1,:]
full_fig = get_surface_plot(xyz, labels=labels, angle=angle)

# %%
xyz = noisy_full_sphere[0,:], noisy_full_sphere[1,:], noisy_full_sphere[-1,:]
noisy_full_fig = get_surface_plot(xyz, labels=labels, angle=angle)
